# %% [markdown]
# # RUN THINS ON COLAB IF U WANT TO TRAIN THE YOLO V* MODEL

# %%
# !pip install ultralytics

# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="AliqSw96rvdyquOll87q")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov8:: 100%|██████████| 1338/1338 [00:00<00:00, 1972.60it/s]

# %% [markdown]
# ## Here for moving the dataset from the folder to be proffitional using python not manuly

# %%
import shutil

# %%
shutil.move('football-players-detection-1/train',
'football-players-detection-1/football-players-detection-1/train')
# Out:
# 'football-players-detection-1/football-players-detection-1/train'

# %%
shutil.move('football-players-detection-1/test',
'football-players-detection-1/football-players-detection-1/test')
# Out:
# 'football-players-detection-1/football-players-detection-1/test'

# %%
shutil.move('football-players-detection-1/valid',
'football-players-detection-1/football-players-detection-1/valid')
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %% [markdown]
# # Training the yolov8 model to detect each person in witch team

# %%
# !yolo task=detect mode=train model=yolov8x.pt data{dataset.location}/data.yaml epochs=100 ingsz=640
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\Programe\Ai\CV\work\Football Analysis\venv\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "D:\Programe\Ai\CV\work\Football Analysis\venv\Lib\site-packages\ultralytics\cfg\__init__.py", line 907, in entrypoint
#     check_dict_alignment(full_args_dict, {a: ""})
#   File "D:\Programe\Ai\CV\work\Football Analysis\venv\Lib\site-packages\ultralytics\cfg\__init__.py", line 506, in check_dict_alignment
#     raise SyntaxError(string + CLI_HELP_MSG) from e
# SyntaxError: 'datad:\Programe\Ai\CV\work\Football' is not a valid YOLO argument.
#
#     Arguments received: ['yolo', 'task=detect', 'mode=train', 'model=yolov8x.pt', 'datad:\\Programe\\Ai\\CV\\work\\Football', 'Analysis\\training\\football-players-detection-1/data.yaml', 'epochs=100', 'ingsz=640']. Ultralytics 'yolo' commands use the following syntax:
#
# ...

# %%
from ultralytics import YOLO

# Load the model
model = YOLO('yolov8x.pt')

# Train the model
# Use f-string to insert the dataset location correctly
model.train(data=f"{dataset.location}/data.yaml", epochs=100, imgsz=640, name='yolov8x_trained',
    exist_ok=True  # Overwrite if exists
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.14 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.13  Python-3.12.5 torch-2.10.0+cpu CPU (11th Gen Intel Core i7-11370H @ 3.30GHz)
# ...
