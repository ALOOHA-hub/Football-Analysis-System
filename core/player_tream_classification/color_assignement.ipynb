# %% [markdown]
# # This notebook is used to assign colors to the players in the video

# %%
import cv2
import numpy as np
import pandas as pd
import os
import sys
import matplotlib.pyplot as plt
from utils.config_loader import cfg

# %% [markdown]
# ### The player will not upsidedown so take the top half of the image
